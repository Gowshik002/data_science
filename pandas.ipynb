# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowshik002/data_science/blob/main/code_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/laptop_price.csv',encoding='latin-1')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.head(1299)
# Out:
#       laptop_ID Company                                    Product  \
# 0             1   Apple                                MacBook Pro
# 1             2   Apple                                Macbook Air
# 2             3      HP                                     250 G6
# 3             4   Apple                                MacBook Pro
# 4             5   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1294       1312      HP                        Pavilion 15-AW003nv
# 1295       1313    Dell                              Inspiron 3567
# 1296       1314      HP                           Stream 11-Y000na
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       1316  Lenovo                             Yoga 500-14ISK
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3         IPS Panel Retina Display 2560x1600
# ...

# %%
this='Full HD'

# %%
df['Full HD']=df['ScreenResolution'].str.find(this)

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
x=df.pop('Full HD')

# %%
x=x.replace(to_replace=0,value=1)
x=x.replace(to_replace=-1,value=0)

# %%
x
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 1298    10
# 1299     0
# 1300     0
# 1301     0
# 1302     0
# Name: Full HD, Length: 1303, dtype: int64

# %%
data={'Full HD':x}

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#       Full HD
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0
# ...       ...
# 1298       10
# 1299        0
# 1300        0
# 1301        0
# 1302        0
#
# [1303 rows x 1 columns]
